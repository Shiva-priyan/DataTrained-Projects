# %% [markdown]
# # Data description
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travellers saying that flight ticket prices are so unpredictable. Here you will be provided with prices of flight tickets for various airlines between the months of March and June of 2019 and between various cities.
#
# Size of training set: 10683 records
#
# Size of test set: 2671 records
#
# FEATURES: Airline: The name of the airline.
#
# Date_of_Journey: The date of the journey
#
# Source: The source from which the service begins.
#
# Destination: The destination where the service ends.
#
# Route: The route taken by the flight to reach the destination.
#
# Dep_Time: The time when the journey starts from the source.
#
# Arrival_Time: Time of arrival at the destination.
#
# Duration: Total duration of the flight.
#
# Total_Stops: Total stops between the source and destination.
#
# Additional_Info: Additional information about the flight
#
# Price: The price of the ticket

# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
train = pd.read_excel('Flight_Data_Train.xlsx',parse_dates=["Date_of_Journey"])
test = pd.read_excel('Flight_Test_set.xlsx',parse_dates=["Date_of_Journey"])

# %%
train.shape
# Out:
# (10683, 11)

# %%
test.shape
# Out:
# (2671, 10)

# %%
train['source'] = 1
test['source'] = 0

# %%
df = pd.concat([train,test])
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      2019-03-24  Banglore   New Delhi
# 1             Air India      2019-01-05   Kolkata    Banglore
# 2           Jet Airways      2019-09-06     Delhi      Cochin
# 3                IndiGo      2019-12-05   Kolkata    Banglore
# 4                IndiGo      2019-01-03  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India      2019-06-06   Kolkata    Banglore
# 2667             IndiGo      2019-03-27   Kolkata    Banglore
# 2668        Jet Airways      2019-06-03     Delhi      Cochin
# 2669          Air India      2019-06-03     Delhi      Cochin
# 2670  Multiple carriers      2019-06-15     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4           BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                     ...      ...           ...      ...         ...
# 2666        CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667              CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668        DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669        DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670        DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#      Additional_Info    Price  source
# 0            No info   3897.0       1
# 1            No info   7662.0       1
# 2            No info  13882.0       1
# 3            No info   6218.0       1
# 4            No info  13302.0       1
# ...              ...      ...     ...
# 2666         No info      NaN       0
# 2667         No info      NaN       0
# 2668         No info      NaN       0
# 2669         No info      NaN       0
# 2670         No info      NaN       0
#
# [13354 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# source                0
# dtype: int64

# %% [markdown]
# We have 1 missing value in Route and Total stops, 2671 missing value in Price

# %%
df[df['Route'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India      2019-06-05  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price  source
# 9039  09:25 07 May  23h 40m         NaN         No info  7480.0       1

# %% [markdown]
# we can understand Both Route and Total stops has nan value in the same place

# %%
df.loc[(df['Source'] == 'Delhi') & (df['Destination'] == 'Cochin') & (df['Airline'] == 'Air India') & (df['Duration'] == '23h 40m') & (df['Price'] == 7480.0)]
# Out:
#         Airline Date_of_Journey Source Destination            Route Dep_Time  \
# 1616  Air India      2019-05-24  Delhi      Cochin  DEL → MAA → COK    09:45
# 2554  Air India      2019-05-15  Delhi      Cochin  DEL → MAA → COK    09:45
# 4351  Air India      2019-06-27  Delhi      Cochin  DEL → MAA → COK    09:45
# 7896  Air India      2019-12-06  Delhi      Cochin  DEL → MAA → COK    09:45
# 9039  Air India      2019-06-05  Delhi      Cochin              NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price  source
# 1616  09:25 25 May  23h 40m      1 stop         No info  7480.0       1
# 2554  09:25 16 May  23h 40m      1 stop         No info  7480.0       1
# 4351  09:25 28 Jun  23h 40m      1 stop         No info  7480.0       1
# 7896  09:25 13 Jun  23h 40m      1 stop         No info  7480.0       1
# 9039  09:25 07 May  23h 40m         NaN         No info  7480.0       1

# %%
df.at[9039, 'Route'] = 'DEL → MAA → COK'

# %%
df.at[9039, 'Total_Stops'] = '1 stop'

# %%
df.loc[[9039]]
# Out:
#         Airline Date_of_Journey Source Destination            Route Dep_Time  \
# 9039  Air India      2019-06-05  Delhi      Cochin  DEL → MAA → COK    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price  source
# 9039  09:25 07 May  23h 40m      1 stop         No info  7480.0       1

# %%
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 0
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# source                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 246

# %%
df= df.drop_duplicates()

# %%
df.shape
# Out:
# (13108, 12)

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                     float64
# source                      int64
# dtype: object

# %% [markdown]
# # Data Visualtisation

# %%
plt.figure(figsize=[20,18])
sns.countplot(df['Airline'])
print(df['Airline'].value_counts())
plt.show()
# Out:
# Jet Airways                          4586
# IndiGo                               2552
# Air India                            2127
# Multiple carriers                    1539
# SpiceJet                             1023
# Vistara                               607
# Air Asia                              405
# GoAir                                 239
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
plt.figure(figsize=[20,18])
sns.countplot(df['Source'])
print(df['Source'].value_counts())
plt.show()
# Out:
# Delhi       5473
# Kolkata     3567
# Banglore    2729
# Mumbai       883
# Chennai      456
# Name: Source, dtype: int64

# %% [markdown]
# Maximum flights take-off from Delhi and Least flights takes off from Chennai.

# %%
plt.figure(figsize=[20,18])
sns.countplot(df['Destination'])
print(df['Destination'].value_counts())
plt.show()
# Out:
# Cochin       5473
# Banglore     3567
# Delhi        1582
# New Delhi    1147
# Hyderabad     883
# Kolkata       456
# Name: Destination, dtype: int64

# %% [markdown]
# Maximum flights lands at Cochin and least flights lands at Kolkata

# %%
plt.figure(figsize=[20,18])
sns.countplot(df['Total_Stops'])
print(df['Total_Stops'].value_counts())
plt.show()
# Out:
# 1 stop      7053
# non-stop    4321
# 2 stops     1678
# 3 stops       54
# 4 stops        2
# Name: Total_Stops, dtype: int64

# %%
plt.figure(figsize=[20,18])
sns.countplot(df['Additional_Info'])
print(df['Additional_Info'].value_counts())
plt.show()
# Out:
# No info                         10309
# In-flight meal not included      2366
# No check-in baggage included      394
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 2 Long layover                      1
# 1 Short layover                     1
# Red-eye flight                      1
# Name: Additional_Info, dtype: int64

# %% [markdown]
# we have many flights with No info

# %%
df['Additional_Info'] = df['Additional_Info'].replace('No Info','No info')

# %%
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      2019-03-24  Banglore   New Delhi
# 1             Air India      2019-01-05   Kolkata    Banglore
# 2           Jet Airways      2019-09-06     Delhi      Cochin
# 3                IndiGo      2019-12-05   Kolkata    Banglore
# 4                IndiGo      2019-01-03  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India      2019-06-06   Kolkata    Banglore
# 2667             IndiGo      2019-03-27   Kolkata    Banglore
# 2668        Jet Airways      2019-06-03     Delhi      Cochin
# 2669          Air India      2019-06-03     Delhi      Cochin
# 2670  Multiple carriers      2019-06-15     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2     DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3           CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4           BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                     ...      ...           ...      ...         ...
# 2666        CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667              CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668        DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669        DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670        DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#      Additional_Info    Price  source
# 0            No info   3897.0       1
# 1            No info   7662.0       1
# 2            No info  13882.0       1
# 3            No info   6218.0       1
# 4            No info  13302.0       1
# ...              ...      ...     ...
# 2666         No info      NaN       0
# 2667         No info      NaN       0
# 2668         No info      NaN       0
# 2669         No info      NaN       0
# 2670         No info      NaN       0
#
# [13108 rows x 12 columns]

# %%
df.drop(['Date_of_Journey','Route','Dep_Time','Arrival_Time'],axis=1,inplace=True)

# %%
df
# Out:
#                 Airline    Source Destination Duration Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m    non-stop
# 1             Air India   Kolkata    Banglore   7h 25m     2 stops
# 2           Jet Airways     Delhi      Cochin      19h     2 stops
# 3                IndiGo   Kolkata    Banglore   5h 25m      1 stop
# 4                IndiGo  Banglore   New Delhi   4h 45m      1 stop
# ...                 ...       ...         ...      ...         ...
# 2666          Air India   Kolkata    Banglore  23h 55m      1 stop
# 2667             IndiGo   Kolkata    Banglore   2h 35m    non-stop
# 2668        Jet Airways     Delhi      Cochin   6h 35m      1 stop
# 2669          Air India     Delhi      Cochin  15h 15m      1 stop
# 2670  Multiple carriers     Delhi      Cochin  14h 20m      1 stop
#
#      Additional_Info    Price  source
# 0            No info   3897.0       1
# 1            No info   7662.0       1
# 2            No info  13882.0       1
# 3            No info   6218.0       1
# 4            No info  13302.0       1
# ...              ...      ...     ...
# 2666         No info      NaN       0
# 2667         No info      NaN       0
# 2668         No info      NaN       0
# 2669         No info      NaN       0
# 2670         No info      NaN       0
#
# [13108 rows x 8 columns]

# %%
df['Duration']=  df['Duration'].str.replace("h", '*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# %%
df
# Out:
#                 Airline    Source Destination  Duration Total_Stops  \
# 0                IndiGo  Banglore   New Delhi       170    non-stop
# 1             Air India   Kolkata    Banglore       445     2 stops
# 2           Jet Airways     Delhi      Cochin      1140     2 stops
# 3                IndiGo   Kolkata    Banglore       325      1 stop
# 4                IndiGo  Banglore   New Delhi       285      1 stop
# ...                 ...       ...         ...       ...         ...
# 2666          Air India   Kolkata    Banglore      1435      1 stop
# 2667             IndiGo   Kolkata    Banglore       155    non-stop
# 2668        Jet Airways     Delhi      Cochin       395      1 stop
# 2669          Air India     Delhi      Cochin       915      1 stop
# 2670  Multiple carriers     Delhi      Cochin       860      1 stop
#
#      Additional_Info    Price  source
# 0            No info   3897.0       1
# 1            No info   7662.0       1
# 2            No info  13882.0       1
# 3            No info   6218.0       1
# 4            No info  13302.0       1
# ...              ...      ...     ...
# 2666         No info      NaN       0
# 2667         No info      NaN       0
# 2668         No info      NaN       0
# 2669         No info      NaN       0
# 2670         No info      NaN       0
#
# [13108 rows x 8 columns]

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = oe.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Airline  Source  Destination  Duration  Total_Stops  Additional_Info  \
# 0         3.0     0.0          5.0       170          4.0              7.0
# 1         1.0     3.0          0.0       445          1.0              7.0
# 2         4.0     2.0          1.0      1140          1.0              7.0
# 3         3.0     3.0          0.0       325          0.0              7.0
# 4         3.0     0.0          5.0       285          0.0              7.0
# ...       ...     ...          ...       ...          ...              ...
# 2666      1.0     3.0          0.0      1435          0.0              7.0
# 2667      3.0     3.0          0.0       155          4.0              7.0
# 2668      4.0     2.0          1.0       395          0.0              7.0
# 2669      1.0     2.0          1.0       915          0.0              7.0
# 2670      6.0     2.0          1.0       860          0.0              7.0
#
#         Price  source
# 0      3897.0       1
# 1      7662.0       1
# 2     13882.0       1
# 3      6218.0       1
# 4     13302.0       1
# ...       ...     ...
# 2666      NaN       0
# 2667      NaN       0
# 2668      NaN       0
# 2669      NaN       0
# 2670      NaN       0
#
# [13108 rows x 8 columns]

# %%
df.describe()
# Out:
#             Airline        Source   Destination      Duration   Total_Stops  \
# count  13108.000000  13108.000000  13108.000000  13108.000000  13108.000000
# mean       3.990616      1.955676      1.437672    631.024184      1.455294
# std        2.374939      1.186289      1.477846    500.762897      1.817298
# min        0.000000      0.000000      0.000000      5.000000      0.000000
# 25%        3.000000      2.000000      0.000000    170.000000      0.000000
# 50%        4.000000      2.000000      1.000000    505.000000      0.000000
# 75%        4.000000      3.000000      2.000000    910.000000      4.000000
# max       11.000000      4.000000      5.000000   2860.000000      4.000000
#
#        Additional_Info         Price        source
# count     13108.000000  10463.000000  13108.000000
# mean          6.594141   9026.642454      0.798215
# std           0.823699   4624.653227      0.401348
# min           0.000000   1759.000000      0.000000
# 25%           7.000000   5224.000000      1.000000
# 50%           7.000000   8266.000000      1.000000
# 75%           7.000000  12343.500000      1.000000
# max           8.000000  79512.000000      1.000000

# %% [markdown]
# There are chances of having outliers, when the difference between 75% and Max is more

# %% [markdown]
# # Correlation

# %%
for i in df.columns:
    plt.figure(figsize=[12,6])
    plt.scatter(x = df[i] ,y = df['Price'] , color = 'c')
    plt.title('Scatter plot of {} vs Price'.format(i))
    plt.show()

# %%
plt.figure(figsize=[15,10])
sns.heatmap(df.corr(),annot=True,linewidths=2.0)
plt.show()

# %% [markdown]
# Observations:
#
# Destination is positively correlated to Total_stops.
#
# Duration is positviely correlated to Price and negatively correlated to Total_Stops.
#
# Total_Stops is negatively correlated to Price and Duration. And positively correlated to Additional_Info and Destination.
#
# Additional_Info is positively correlated to Total_Stops.
#
# Price is negatively correlated to Total_Stops and Duration.

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'source'],
#       dtype='object')

# %%
for i in df.columns:
    plt.figure(figsize=[15,10])
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# We can see outliers in Source, Price,Additional_Info,Duration,Source,Airline. However, we will only treat outliers for Duration column as all the other columns are categorical in nature and Price is our target variable.

# %% [markdown]
# # Data Distribution

# %%
for i in df.columns:
    plt.figure(figsize=[10,12])
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# # Outliers

# %%
IQR = df['Duration'].quantile(0.75) - df['Duration'].quantile(0.25)
lower_bridge=df['Duration'].quantile(0.25)-IQR*1.5
upper_bridge=df['Duration'].quantile(0.75)+IQR*1.5
print('Lower_bridge is',lower_bridge)
print('Upper_bridge is',upper_bridge)
# Out:
# Lower_bridge is -0.6866359832640931
# Upper_bridge is 15.91681532345206

# %%
sns.boxplot(df['Duration'])
plt.title('After removing the outliers')
plt.show()

# %% [markdown]
# # Checking and removing the skewness

# %%
df.skew()
# Out:
# Airline            0.714589
# Source            -0.420657
# Destination        1.232043
# Duration           0.191422
# Total_Stops        0.627085
# Additional_Info   -2.096422
# Price              1.857641
# source            -1.486293
# dtype: float64

# %% [markdown]
# we will remove skewness only from Duration as other variables are categorical in nature and Price is the target variable.

# %%
df['Duration'] = np.cbrt(df['Duration'])

# %%
df.skew()
# Out:
# Airline            0.714589
# Source            -0.420657
# Destination        1.232043
# Duration          -0.044022
# Total_Stops        0.627085
# Additional_Info   -2.096422
# Price              1.857641
# source            -1.486293
# dtype: float64

# %%
df.head()
# Out:
#    Airline  Source  Destination  Duration  Total_Stops  Additional_Info  \
# 0      3.0     0.0          5.0  1.769407          4.0              7.0
# 1      1.0     3.0          0.0  1.969075          1.0              7.0
# 2      4.0     2.0          1.0  2.186030          1.0              7.0
# 3      3.0     3.0          0.0  1.901508          0.0              7.0
# 4      3.0     0.0          5.0  1.873961          0.0              7.0
#
#      Price  source
# 0   3897.0       1
# 1   7662.0       1
# 2  13882.0       1
# 3   6218.0       1
# 4  13302.0       1

# %% [markdown]
# # Separating train and test from the dataset

# %%
train = df.loc[df['source'] == 1]
test = df.loc[df['source'] == 0]

# %%
train.drop('source', axis = 1, inplace = True)
test.drop('source', axis = 1, inplace = True)
test.drop('Price', axis = 1, inplace = True)

# %%
x = train.drop('Price', axis = 1)
y = train['Price']

# %%
x
# Out:
#        Airline  Source  Destination  Duration  Total_Stops  Additional_Info
# 0          3.0     0.0          5.0  1.769407          4.0              7.0
# 1          1.0     3.0          0.0  1.969075          1.0              7.0
# 2          4.0     2.0          1.0  2.186030          1.0              7.0
# 3          3.0     3.0          0.0  1.901508          0.0              7.0
# 4          3.0     0.0          5.0  1.873961          0.0              7.0
# ...        ...     ...          ...       ...          ...              ...
# 10678      0.0     3.0          0.0  1.744970          4.0              7.0
# 10679      1.0     3.0          0.0  1.751339          4.0              7.0
# 10680      4.0     0.0          2.0  1.780680          4.0              7.0
# 10681     10.0     0.0          5.0  1.757528          4.0              7.0
# 10682      1.0     2.0          1.0  1.994737          1.0              7.0
#
# [10463 rows x 6 columns]

# %%
y
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 10678     4107.0
# 10679     4145.0
# 10680     7229.0
# 10681    12648.0
# 10682    11753.0
# Name: Price, Length: 10463, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_x = sc.fit_transform(x)

# %%
df_x=pd.DataFrame(df_x,columns=x.columns)

# %%
x=df_x

# %% [markdown]
# # Finding the Best Random State

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
maxr2=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    lm.score(x_train,y_train)
    lm.score(x_test,y_test)
    ypred=lm.predict(x_test)
    acc=r2_score(y_test,ypred)
    if acc>maxr2:
        maxr2=acc
        maxRS=i
print('Best accuracy is',maxr2, 'for random state',maxRS)
# Out:
# Best accuracy is 0.4649168827902358 for random state 69

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
lm=LinearRegression()
dtc=DecisionTreeRegressor()
rf=RandomForestRegressor()

model =[lm,dtc,rf]
for i in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=69)
    i.fit(x_train,y_train)
    pred=i.predict(x_test)
    print('R2 score for',i, 'is',r2_score(pred,y_test))
    cvs=cross_val_score(i,x,y,cv=5)
    print('Cross validation score for',i, 'is',cvs.mean())
    print('Difference between R2 score and Cross Validation Score is',r2_score(pred,y_test) - cvs.mean())
    print('\t')
    print('\t')
# Out:
# R2 score for LinearRegression() is -0.1043075210350719
# Cross validation score for LinearRegression() is 0.40660457245834103
# Difference between R2 score and Cross Validation Score is -0.5109120934934129
#
#
# R2 score for DecisionTreeRegressor() is 0.5992216604073917
# Cross validation score for DecisionTreeRegressor() is 0.6621040886373388
# Difference between R2 score and Cross Validation Score is -0.06288242822994716
#
#
# R2 score for RandomForestRegressor() is 0.6267196872814529
# Cross validation score for RandomForestRegressor() is 0.6979638736719886
# Difference between R2 score and Cross Validation Score is -0.07124418639053576

# %% [markdown]
# Radom Forest Regressor is giving least difference between R2 score and Cross validation score

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['mse', 'mae']
}

# %%
GCV = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 3)
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]})

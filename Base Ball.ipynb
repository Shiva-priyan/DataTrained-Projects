# %% [markdown]
# # Problem Definition

# %% [markdown]
# #This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -(independent variables) Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -(dependent variables) Output: Number of predicted wins (W)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Base ball')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Analysing Data

# %%
df.shape
# Out:
# (30, 17)

# %%
#we have 30 rows and 17 columns
#This Is regression Problem, because target is in numerical/integer format

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# there is no null value, let us have a clear view with the help of heatmap

# %%
sns.heatmap(df.isnull())
plt.title('NUll Values Heatmap',fontsize=10)
# Out:
# Text(0.5, 1.0, 'NUll Values Heatmap')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [raw]
#  Observation
#  1.mean and median are very close, so the Data is normally distributed in most of the cases.
#  2.Between 75% and Max there are gap, so there may be some Outliers present in data.
#  3.It is known that total count is 30 , mean for every columns such as winning - 80 and average runs scored here is 688 and so on.. There is a Minimum value and maximum value for each column, suppose we take HR (HOME RUNS) , min home run scored is 100 and maximun home run scored is 232. We can also have a watch on standard deviation of the whole data.

# %% [markdown]
# # Outliers and Data Visualisation

# %%
sns.pairplot(df)

# %% [markdown]
# Pairplot has been constructed above to show us the distribution of each variables and also to show the relationship between each of the two variables.

# %% [markdown]
# / shows positive correlation and \ shows Negative correlation

# %%
corr_hmap=df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [raw]
# From the above heatmap, a picture of the map is prepared where it is show that which variables are showing positive relationship and which are showing the negative relationship.
#
# the black dots represent negative corelation where as off white color shows the positive corelation.
#
# W is positively correlated to SV, SHO, BB, HR, 2B, R and negatively correlated to ER, RA and ERA.
# R is positively correlated to CG,BB,HR, 2B,H,AB,W
# AB is positively correlated to E,ER,ERA,RA,SB,3B,2B,H,R
# H is positively correlated to CG,E,ER,ERA,RA,SB,3B,2B,AB and R,while negatively correlated to SO
# 2B is positively correlated to CG,SB,BB,3B,H,AB,R,W
# 3B is positively correlated to E,ER,ERA,RA,SB,2B,H,AB while negatively correlated to BB and HR
# HR is positively correlated to SO,BB,R and W, while negatively correlated to 3B
# BB is positively correlated to SHO,CG,HR,2B,R,W and negatively correlated to ERA,ER,RA
# SO is positively correlated to SHO,CG,SO,HR and negatively correlated to H
# SB is positively correlated to 3B,H,AB
# RA,ERA and ER are negatively correlated to SV,SHO and W.
# RA,ER and ERA are correlated to 3B,H and AB
# CG is positively correlated to BB,2B
# SHO and SV are negatively correlated to ERA,ER,RA and positively correlated to W
# E is positively correlated to AB

# %%
for i in range (0,len(df.columns)):
    plt.subplot(121)
    sns.distplot(df[df.columns[i]])
    plt.subplot(122)
    df[df.columns[i]].plot.box(figsize=(12,6))
    plt.figure(figsize=(12,6))
    
plt.show()

# %% [markdown]
# Observation:
#
# ERA, SHO,SV,R and E has got outliers.

# %%
for i in df.columns:
    plt.figure(figsize=[10,5])
    plt.scatter(x = df[i] ,y = df['W'] , color = 'g')
    plt.title('Scatter diagram for {} in relationship with W '.format(i))
    plt.show()

# %% [markdown]
# # checking the Correlation with target variable

# %%
plt.figure(figsize=[15,10])
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color = 'g')
plt.title('Correlation')
plt.show()

# %% [raw]
# SV, BB,SHO,R,2B,HR,SO,CG and H are positively correlated to W
# AB,E,SB,3B,ER,RA,ERA are negatively correlated to W

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# Removing Outliers through zscore

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
# Out:
# (30, 17)

# %%
df1=df.loc[(z_score<3).all(axis=1)]
print(df1.shape)
# Out:
# (29, 17)

# %% [markdown]
# After applying zscore, the shape of the data has changed from 30,17 to 29,17 which shows that with zscore we are able to remove 1 row , Hence our new data shape is (29,17)

# %% [markdown]
# Data loss is 3%, hence we can remove the outliers

# %% [markdown]
# # Splitting the data set

# %%
x = df1.drop('W',axis=1)

# %%
y = df1['W']

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# we need to remove skewness from R,H,HR,CG,SHO,SV and E

# %%
from sklearn.preprocessing import power_transform

# %%
df_x=power_transform(x)

# %%
df_x=pd.DataFrame(df_x,columns=x.columns)

# %%
df_x.skew()
# Out:
# R     -0.024842
# AB     0.000000
# H      0.000000
# 2B    -0.052793
# 3B    -0.075139
# HR     0.000448
# BB    -0.008572
# SO     0.051530
# SB    -0.009570
# RA    -0.011974
# ER    -0.004988
# ERA   -0.000401
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# Skewness has been removed

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_scaled=ss.fit_transform(x)
x=pd.DataFrame(x_scaled,columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
et=ExtraTreesRegressor()
et.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(et.feature_importances_)
# Out:
# [0.05667662 0.01009004 0.01968464 0.01689498 0.00981188 0.02425862
#  0.02219401 0.03138905 0.01424333 0.19787103 0.18494975 0.20569297
#  0.01015161 0.01728543 0.15822075 0.02058528]

# %%
plt.figure(figsize=(12,6))
plt.title('Important Features',fontsize=15)
feat_importance=pd.Series(et.feature_importances_,index=x.columns)
feat_importance.nlargest().plot(kind='barh',color = 'y')
plt.show()

# %% [markdown]
# We can see that SV(Saves),RA(Runs Allowed),ERA(Earned Run Average) are the most important Features for prediction of Number of win counts for our Machine Learning Model

# %% [markdown]
# # Model

# %%
## Importing machine learning Library
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1)
    print('\n')
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean())
    print('\n')
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std())
    print('\n')
    print('Training accuracy',clf.score(x_train,y_train))
    print('\n')
    print('Test Accuracy',clf.score(x_test,y_test))
    print('\n')
    print('MAE',mean_absolute_error(y_test,pred))
    print('\n')
    print('MSE',mean_squared_error(y_test,pred))
    print('\n')
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    
    return final_r

# %%
#LINERAR rEGRESSION
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 64 is 0.8556290952095521
#
#
# cross validation score 0.03762866049631375
#
#
# Standard Deviation 0.570477976644222
#
#
# Training accuracy 0.9611734965562408
#
#
# Test Accuracy 0.8458464532843802
#
#
# MAE 4.477012133523914
#
#
# MSE 23.516979960060652
#
#
# RMSE 4.8494308903273025
# 64

# %%
## Lasso
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 82 is 0.9615885854918899
#
#
# cross validation score 0.41522524523739046
#
#
# Standard Deviation 0.7424270277748934
#
#
# Training accuracy 0.8536948537194158
#
#
# Test Accuracy 0.8728529345518802
#
#
# MAE 3.683851279837569
#
#
# MSE 19.396991206696498
#
#
# RMSE 4.404201540199597
# 82

# %%
## Ridge
rigde=Ridge()
maxr2_score(rigde,x,y)
# Out:
# max r2 score corresponding to 75 is 0.9704140728447963
#
#
# cross validation score 0.33747787690695735
#
#
# Standard Deviation 0.8451497257649958
#
#
# Training accuracy 0.9277076354896958
#
#
# Test Accuracy 0.9186249571400574
#
#
# MAE 2.926360631878661
#
#
# MSE 12.414214871855677
#
#
# RMSE 3.523381170389556
# 75

# %%
## Decision Tree
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 94 is 0.8024118738404453
#
#
# cross validation score -2.161839580367519
#
#
# Standard Deviation 3.905493742442768
#
#
# Training accuracy 1.0
#
#
# Test Accuracy 0.5105608157319738
#
#
# MAE 7.333333333333333
#
#
# MSE 74.66666666666667
#
#
# RMSE 8.640987597877148
# 94

# %%
## KNN
knn=KNeighborsRegressor()
maxr2_score(knn,x,y)
# Out:
# max r2 score corresponding to 44 is 0.7985333333333334
#
#
# cross validation score 0.03984806734728634
#
#
# Standard Deviation 0.8728903591165531
#
#
# Training accuracy 0.5941299842493576
#
#
# Test Accuracy 0.7437873270211217
#
#
# MAE 5.699999999999998
#
#
# MSE 39.086666666666645
#
#
# RMSE 6.251933034403571
# 44

# %%
##SVm
svm=SVR()
maxr2_score(svm,x,y)
# Out:
# max r2 score corresponding to 54 is 0.2405752188196617
#
#
# cross validation score -0.29223763346879383
#
#
# Standard Deviation 0.47658296591058474
#
#
# Training accuracy 0.21842586962300747
#
#
# Test Accuracy 0.15613434724239017
#
#
# MAE 9.962044058063796
#
#
# MSE 128.73639347068868
#
#
# RMSE 11.346206126749534
# 54

# %%
## random Forest
rf=RandomForestRegressor()
maxr2_score(rf,x,y)
# Out:
# max r2 score corresponding to 64 is 0.7695459600760455
#
#
# cross validation score -0.5989232381830709
#
#
# Standard Deviation 2.244338455379657
#
#
# Training accuracy 0.9430385828566693
#
#
# Test Accuracy 0.6792540058266572
#
#
# MAE 6.048333333333329
#
#
# MSE 48.931583333333286
#
#
# RMSE 6.995111388200568
# 64

# %%
## AdaBoost
Adb=AdaBoostRegressor(base_estimator=lasso)
maxr2_score(Adb,x,y)
# Out:
# max r2 score corresponding to 46 is 0.9192991821269622
#
#
# cross validation score -0.04285165392138821
#
#
# Standard Deviation 0.6311039563493464
#
#
# Training accuracy 0.6875523962876284
#
#
# Test Accuracy 0.4712614154977808
#
#
# MAE 8.285632449832464
#
#
# MSE 80.6620085023941
#
#
# RMSE 8.981203065424705
# 46

# %%
## Gradient Boost
gnb=GradientBoostingRegressor()
maxr2_score(gnb,x,y)
# Out:
# max r2 score corresponding to 47 is 0.8112865894806871
#
#
# cross validation score -1.4091830925068491
#
#
# Standard Deviation 3.854863981723322
#
#
# Training accuracy 0.9999998270821823
#
#
# Test Accuracy 0.7570154639399392
#
#
# MAE 5.257022274637741
#
#
# MSE 37.06864089005149
#
#
# RMSE 6.088402162312497
# 47

# %% [markdown]
# We will choose ridge regressor as our best model becasue the difference between the Test accuracy & Training accuracy score is very less as compare to other models

# %% [markdown]
# # Hyperparameter Tuning

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=75,test_size=.20)
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],'solver': ['auto', 'svd', 'cholesky', 'lsqr']}
glf=GridSearchCV(estimator=ridge,param_grid=parameters,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'alpha': 1, 'solver': 'svd'}

# %%
ridge1=Ridge(alpha=1,solver='svd')
ridge1.fit(x_train,y_train)
pred=ridge1.predict(x_test)
print('Training accuracy',ridge1.score(x_train,y_train))
print('\n')
print('Test Accuracy',ridge1.score(x_test,y_test))
print('\n')

print('Error:')
print('MAE',mean_absolute_error(y_test,pred))
print('\n')
print('MSE',mean_squared_error(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('R2 score',r2_score(pred,y_test))
# Out:
# Training accuracy 0.9152937309859137
#
#
# Test Accuracy 0.9704140728447963
#
#
# Error:
# MAE 1.73911496968793
#
#
# MSE 3.998209322501826
#
#
# RMSE 1.9995522805122716
#
#
# R2 score 0.968362564335213

# %% [markdown]
# we can see that our test accuracy has imporved from 91.96 to 96.56.

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(ridge1,'baseballR_1.pkl')
# Out:
# ['baseballR_1.pkl']

# %%
loaded_model=joblib.load('baseballR_1.pkl')
prediction=loaded_model.predict(x_test)
